# %%
import sys

# %%
# to declare a string in python we use we use single quote or double quotes
a = "hello python"
print(type(a)) # a class of a string is str
print(sys.getsizeof(a)) # memory
print(id(a)) # memory address
# Out:
# <class 'str'>
# 53
# 2627267429488

# %%
b='a'
print(type(b))
print(sys.getsizeof(b))
print(id(b)) # memory address
# Out:
# <class 'str'>
# 42
# 140714862173760

# %%
c=''
print(type(c))
print(sys.getsizeof(c))
print(id(c)) # memory address
# Out:
# <class 'str'>
# 41
# 140714862132384

# %%
d=''
print(type(d))
print(sys.getsizeof(d))
print(id(d)) # memory address
# Out:
# <class 'str'>
# 41
# 140714862132384

# %% [markdown]
# #### string methods

# %%
s="hello"

s.capitalize() #to capitalize first letter of a word
# Out:
# 'Hello'

# %%
s="hello world"
s.casefold() #this returns lower case for any jumbeled case
# Out:
# 'hello world'

# %% [markdown]
# #### split() method: splits a string and return an array or list

# %%
a="hello sir"
a.split() #it splits a string and return an array
# Out:
# ['hello', 'sir']

# %%
a.split("o")
# Out:
# ['hell', ' sir']

# %%
a.split("w") #if the substring is not found split returns string in form of list of str [list(str)]
# Out:
# ['hello sir']

# %%
a.split(None)
# Out:
# ['hello', 'sir']

# %% [markdown]
# #### isdigit method

# %%
n="12"
n.isdigit() #if strings have all the digits then returns true else return false
# Out:
# True

# %%
f="alpha123"
f.isdigit() #isdigit returns false incase any no-digit character in string
# Out:
# False

# %%
f.isalnum() #it checks whether a string is alphanumeric or not. if yes returns true else false
# Out:
# True

# %% [markdown]
# #### replace

# %%
changed=f.replace("123", "numeric") #replace: it replace the string with asked string
print(changed)
# Out:
# alphanumeric

# %%
t="2defa"
t.isspace() #it checks space
# Out:
# False

# %%
pr="is printable or not"
pr.isprintable()
# Out:
# True

# %% [markdown]
# #### find

# %%
s="this is my text"
s.find("t") #it returns index of first found string
# Out:
# 0

# %%
if t.find("a") >=0:
    print('available')
else:
    print("not available")
# Out:
# not available

# %%
g="start over in to the python-language"
k=g.count(" ")
print("total words into string is", k+1)
# Out:
# total words into string is 6

# %% [markdown]
# #### count

# %%
para="this is the python learning code"
para.count("t") #it returns the total count of asked string
# Out:
# 3

# %%
a="abcdefghijklmnopqrstuvwxyz"
a[1:3]
a[0:3]  #it returns
# Out:
# 'abc'

# %%
a[0:24:3] # [start: end-1: skipping by the value]
# Out:
# 'adgjmpsv'

# %%
a[0:26]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
str="python"
print(len(str)) #it returns the length of string
# Out:
# 6

# %%
str="python"
print(str.endswith("o")) #it checks whether a string endswith asked string or not and returns boolean response
# Out:
# False

# %%
names=["anay", "akash", "abhinay", "akshat"]
for x in names:
    if x == "akshat":
        break
    print(x)
# Out:
# anay
# akash
# abhinay

# %% [markdown]
# triangle/pyramid

# %%
n=6
for i in range(0, n):
    print(" " * (n-i), end=" ")
    for j in range(0, i+1):
        print("*", end=" ")
        
    
    print()
# Out:
#        *
#       * *
#      * * *
#     * * * *
#    * * * * *
#   * * * * * *

# %% [markdown]
# #### operation on digits

# %%
n=2
for i in range(1, 10): #why until 9 why not 10
    print(n, 'x', i, '=', n*i)
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18

# %%
n=8
print(type(n))
# Out:
# <class 'int'>

# %%
n.is_integer()
# Out:
# True

# %%
b=234
sys.getsizeof(b)
# Out:
# 28

# %%
x= int(3.25)
print(x)
# Out:
# 3

# %%
fl= float(3)
print(fl)
# Out:
# 3.0

# %%
st= int("2")
bt= int("2")
print(st+bt)
# Out:
# 4

# %% [markdown]
# #### list

# %%
l1 = ["alpha123", "#", 8, 8.2,"great"]
v=l1[0]
v.isalnum()
flt=l1[3]
c= int(flt)
print(c)
inte= l1[2]
z= float(inte)
print(z)
# Out:
# 8
# 8.0

# %%
l2= [1,2,8,6,5,7,9,2,4,2,3,6,4]
#l2.sort()
#print(l2)
#l2.reverse()
#print(l2)
#l2.append(6)
#print(l2)
#l2.insert(0,86)
#print(l2)
#l2.pop(7)
res= sum(l2)
print(res)
# Out:
# 59

# %% [markdown]
# #### tuple

# %%
q=()
q=(1,1,2,8,6,5,7,9,2,4,2,3,6,4)
q.count(2)
# Out:
# 3

# %% [markdown]
# #### dictionary

# %%
d= {
    "veggies": "potato",
    "fruits": "apple",
    "name": "sky",
    "marks": "100",
    "list": [6,7,9,2,8]
    }
print(d["veggies"])
print(d["fruits"])
d.keys()# it returns only keys(left hand side things)
d.update({"language":"python"}) #it updates the dictionary
d.items()#returns the whole dictionary with keys and values
d.get("veggies") #it returns the value(right hand side things)
# Out:
# potato
# apple
# 'potato'

# %% [markdown]
# #### sets

# %%
s=set()
s.add(1)
s.add(2)
s.add(6)
len(s)
s.union({6,11})
s.pop()
#s.clear()
s.remove(2)
